# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 1
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %%
cita = "¿Por qué esta magnífica tecnología científica,\n\tque ahorra trabajo y nos hace la vida mas fácil,\n\t\tnos aporta tan poca felicidad?\n\t\t\tLa repuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino.\n \"Albert Einstein\" "
print(cita)
# Out:
# ¿Por qué esta magnífica tecnología científica,
# 	que ahorra trabajo y nos hace la vida mas fácil,
# 		nos aporta tan poca felicidad?
# 			La repuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino.
#  "Albert Einstein"

# %%
cita2 = """¿Por qué esta magnífica tecnología científica,
	que ahorra trabajo y nos hace la vida mas fácil,
		nos aporta tan poca felicidad?
			La repuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino.
 "Albert Einstein" """

print(cita2)
# Out:
# ¿Por qué esta magnífica tecnología científica,
# 	que ahorra trabajo y nos hace la vida mas fácil,
# 		nos aporta tan poca felicidad?
# 			La repuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino.
#  "Albert Einstein"

# %% [markdown]
# El print, después de imprimir lo que le he indicado dentro de su función, me devuelve al final un None porque al ser una función me tiene que devolver algo, que es un None.
#
# ![image.png](attachment:image.png)

# %%
# Primero muestra el "Hola", después None y por último otro None que no se muestra

print(print("hola"))
# Out:
# hola
# None

# %%
print()

# %%
def suma (n:int, m:int) -> str | list:
    print("hola, estoy imprimiendo")
    
    mi_suma = n + m
    print("la suma es: ", mi_suma)

    if n>2:
        return [n, m, mi_suma]
    else:
        return "ahora quiero devolver un string"

# ahora compruebo dos posibles números
print(suma(1,3)) # n=1 y m=3
print(suma(5,3)) # n=5 y m=3
# Out:
# hola, estoy imprimiendo
# la suma es:  4
# ahora quiero devolver un string
# hola, estoy imprimiendo
# la suma es:  8
# [5, 3, 8]

# %%
# después de \ NO PUEDO ESCRIBIR NADA, ni un espacio. Porque se supone que no tengo sitio

"hola esta es una línea muy larga y la quiero partir\
    por la mitad para que me entre en el código"
# Out:
# 'hola esta es una línea muy larga y la quiero partir    por la mitad para que me entre en el código'

# %% [markdown]
# ## Ejercicio 2
# 1. Escribe el nombre de la calle de tu domicilio
# 2. Escribe el numero de la calle en otra
# 3. Población en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Crea una quinta variable que concatene todas ellas
# 6. Imprimela por pantalla

# %%
# Los espacios en la concatenación de cadenas cómo se muestran en pantalla

calle = "Fernández"
numero = "1"
poblacion = "Ceuta"
codigo = "51001"

direccion = calle + " " + numero + " " + poblacion + " " + codigo
print(direccion)
# Out:
# Fernández 1 Ceuta 51001

# %% [markdown]
# ## Ejercicio 3
# Replica el output del ejercicio dos, pero está vez sin usar una variable intermedia que concatene todas las demas. Realiza este ejercicio en una línea, con un  único `print`

# %%
calle = "Fernández"
numero = "1"
poblacion = "Ceuta"
codigo = "51001"

print(f"{calle} {numero} {poblacion} {codigo}")
# Out:
# Fernández 1 Ceuta 51001

# %% [markdown]
# ## Ejercicio 4
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio
# 3. True = "Ejercicio"
# 4. mi variab1e = "Alpha"
# 5. exec = True
# 6. import = 40
# 7. 81mi_variable = "Agua"
# 8. mi_variable10 = 6

# %%
mi_variable = "Economía"

# %%
otra_var = "Ejercicio 
# falta comillas dobles al final de la cadena"
# Out:
#   Cell In[11], line 1
#     otra_var = "Ejercicio
#                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
True = "Ejercicio"
# True no puede ser usado como nombre de variable
# Out:
#   Cell In[14], line 1
#     True = "Ejercicio"
#     ^
# SyntaxError: cannot assign to True

# %%
mi variab1e = "Alpha"
# no es válida porque tiene espacios
# Out:
#   Cell In[15], line 1
#     mi variab1e = "Alpha"
#        ^
# SyntaxError: invalid syntax

# %%
exec = True

# %%
import = 40
# import es una palabra reservada
# Out:
#   Cell In[17], line 1
#     import = 40
#            ^
# SyntaxError: invalid syntax

# %%
81mi_variable = "Agua"
# no es válido porque empieza con un número
# Out:
#   Cell In[18], line 1
#     81mi_variable = "Agua"
#      ^
# SyntaxError: invalid decimal literal

# %%
mi_variable10 = 6

# %% [markdown]
# ## Ejercicio 5
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = (C × 9 / 5) + 32

# %%
grados = input("Introduce los grados Celsius: ")
# como lo que le introduzo es un str, debo pasarlo a float para hacer la operación
grados = float(grados)
farenheit = (grados * 9 / 5) + 32
print(f"{grados} grados Celsius son {farenheit} grados Fahrenheit")

# podría hacerlo comprobando si el input es un dígito numérico grados.isdigit()
# Out:
# 23.4 grados Celsius son 74.12 grados Fahrenheit

# %% [markdown]
# ## Ejercicio 6
# Comenta en la medida de lo posible el Ejercicio 5. Será suficiente con poner al menos un comentario de línea, y otro multilínea

# %%
# Convesor de grados a farenheit
'''Con este programa
vamos a convertir los grados,
teniendo en cuenta que introducimos str
y debo pasarlo a float.'''
# Out:
# 'Con este programa\nvamos a convertir los grados,\nteniendo en cuenta que introducimos str\ny debo pasarlo a float.'
