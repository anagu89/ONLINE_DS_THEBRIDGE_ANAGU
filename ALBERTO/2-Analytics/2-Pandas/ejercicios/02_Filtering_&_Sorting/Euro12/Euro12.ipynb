# %% [markdown]
# # Ex2 - Filtering and Sorting Data

# %%
# repaso:

def suma (n,m): 
    n = n + m
    return n
# n=2 y m=3, lo que hago es pasarle una copia de sus valores, por eso el return es 5 (la suma)
# pero si le pregunto por n, me dirá n=2 que es su valor inicial, no el resultado de la función


# a esta función, lo que le paso NO son colecciones, por lo qeu cuando yo la ejecuto,
# lo que hago es pasarle una copia de los valores


def agrega (lista, cosa):
    lista.append(cosa)
    return lista

a = 2 
b = 3

print(suma(a,b)) # 5
print(a) # 2 porque es una copia

a = ["hola"]
b = "adios"
print(agrega(a,b)) # aquí se pasa una lista (que es una colección), es la misma flecha en phyton tutor
print(a) # sale ['hola', 'adios'] porque lo he modificado, la lista se ha agrandado
# Out:
# 5
# 2
# ['hola', 'adios']
# ['hola', 'adios']

# %%
# las tuplas son inmutables, es decir, que cuando la creo con 5 objetos no puedo cambiar esos
# objetos por otros 

lista = []
n = 3
tupla = (1,2,n, lista)

# %%
tupla[0] = 0
# esto me da error porque no puedo modificarla después de crearla.
# no puedo asignar algo nuevo a una tupla ya creada
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tupla[0] = 0
#       2 # esto me da error porque no puedo modificarla después de crearla.
#       3 # no puedo asignar algo nuevo a una tupla ya creada
#
# TypeError: 'tuple' object does not support item assignment

# %%
tupla[-1].append("hola")

print(tupla)
# aquí sí puedo porque estoy modificando la lista interna de la tupla que sí es mutable
# Out:
# (1, 2, 3, ['hola'])

# %%
hash(tupla)

# a esta tupla no puedo hacerle el hash porque dentro tiene un elemento no hasheable
# dentro que es una lista, es decir, tengo un elemento que sí es mutable(cambiable)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 hash(tupla)
#
# TypeError: unhashable type: 'list'

# %%
hash(7.9) 
# esto sí lo puedo hashear porque es inmutable
# Out:
# 2075258708292325383

# %%
# los sets, SOLO ADMITEN objetos HASHEABLES
set = {3}
print(set)

set.add(5)
print(set)

set.add([1,2,3])
print(set)
# este me dará error que no puedo introducirle una lista que es no hasheable
# Out:
# {3}
# {3, 5}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 8
#       5 set.add(5)
#       6 print(set)
# ----> 8 set.add([1,2,3])
#       9 print(set)
#      10 # este me dará error que no puedo introducirle una lista que es no hasheable
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# This time we are going to pull data directly from the internet.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called euro12.

# %%
euro12 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image.png)

# %%
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Step 4. Select only the Goal column.

# %%
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# ### Step 5. How many team participated in the Euro2012?

# %%
euro12.Team.nunique()
# Out:
# 16

# %%
# Out:
# array(['Croatia', 'Czech Republic', 'Denmark', 'England', 'France',
#        'Germany', 'Greece', 'Italy', 'Netherlands', 'Poland', 'Portugal',
#        'Republic of Ireland', 'Russia', 'Spain', 'Sweden', 'Ukraine'],
#       dtype=object)

# %%
euro12.shape[0]
# Out:
# 16

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
print(len(euro12)) # filas

print(len(euro12.columns)) # columnas
# Out:
# 16
# 35

# %% [markdown]
# ### Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
d1 = euro12.loc

# %%
# filter only giving the column names

discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']] # <--- poner dos corchetes, sino, loc/iloc
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
# Out:
#              Team  Yellow Cards  Red Cards
# 0         Croatia             9          0
# 1  Czech Republic             7          0
# 2         Denmark             4          0
# 3         England             5          0
# 4          France             6          0

# %% [markdown]
# ### Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
discipline.sort_values(['Red Cards', 'Yellow Cards'], ascending= False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %% [markdown]
# ### Step 9. Calculate the mean Yellow Cards given per Team

# %%
# Out:
# 7.4375

# %% [markdown]
# ### Step 10. Filter teams that scored more than 6 goals

# %%
euro12[euro12['Goals'] > 6]

# como es una máscara booleana, me devuelve un booleano
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %% [markdown]
# También podría haberlo hecho con:
#
# ![image.png](attachment:image.png)

# %%
filtro1 = euro12['Goals'] > 6
euro12_filtro1 = euro12.where(filtro1).dropna()
euro12_filtro1
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany   10.0             32.0              32.0             47.8%
# 13    Spain   12.0             42.0              33.0             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                        80.0           2.0            1.0
# 13            16.0%                       100.0           0.0            1.0
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                    0.0  ...        10.0                 62.6%       63.0
# 13                   0.0  ...        15.0                 93.8%      102.0
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5            49.0      12.0           4.0        0.0     15.0      15.0
# 13           83.0      19.0          11.0        0.0     17.0      17.0
#
#     Players Used
# 5           17.0
# 13          18.0
#
# ...

# %% [markdown]
# ### Step 11. Select the teams that start with G

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
euro12.Team
# Out:
# 0                 Croatia
# 1          Czech Republic
# 2                 Denmark
# 3                 England
# 4                  France
# 5                 Germany
# 6                  Greece
# 7                   Italy
# 8             Netherlands
# 9                  Poland
# 10               Portugal
# 11    Republic of Ireland
# 12                 Russia
# 13                  Spain
# 14                 Sweden
# 15                Ukraine
# Name: Team, dtype: object

# %%
print(type(euro12.Team)) # me da una serie
# Out:
# <class 'pandas.core.series.Series'>

# %%
empezar_G = euro12.Team.str.startswith('G') 
empezar_G
# el str es de buscar con str porque busco por `G`
# ya tengo mi máscara booleana
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# Name: Team, dtype: bool

# %%
empezar_G = euro12[euro12.Team.str.startswith('G')]
empezar_G
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_22896/1100048980.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   mask = euro12.Team.str.contains("(^G)")
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# ...

# %%
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %% [markdown]
# ### Step 12. Select the first 7 columns

# %%
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Step 13. Select all columns except the last 3.

# %%
euro12.iloc[ :, : -3:]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %% [markdown]
# Podemos hacer esto, pero es mejor hacer lo de la siguiente casilla:
#
#
# ![image.png](attachment:image.png)

# %%
# Out:
#    Shooting Accuracy
# 3              50.0%
# 7              43.0%
# 12             22.5%

# %% [markdown]
# Lo correcto sería hacer eso:
#
# ![image.png](attachment:image.png)

# %%
euro12.Team.isin(['England', 'Italy', 'Russia']), ['Team', 'Shooting Accuracy']
# Out:
# (0     False
#  1     False
#  2     False
#  3      True
#  4     False
#  5     False
#  6     False
#  7      True
#  8     False
#  9     False
#  10    False
#  11    False
#  12     True
#  13    False
#  14    False
#  15    False
#  Name: Team, dtype: bool,
#  ['Team', 'Shooting Accuracy'])

# %%
euro12.loc[euro12.Team.isin(['England', 'Italy', 'Russia']), ['Team', 'Shooting Accuracy']]
# una vez filtada, le digo que sólo quiero las columnas de 'Team', 'Shooting Accuracy'
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# df = dataframe
# Out:
# 3     50.0%
# 7     43.0%
# 12    22.5%
# Name: Shooting Accuracy, dtype: object

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.DataFrame()
df2 = pd.DataFrame()
df2['nombre'] = ['A', 'B', 'C']
df_total = pd.concat([df, df2])
df_total
# Out:
#   nombre
# 0      A
# 1      B
# 2      C

# %%
df_total.loc[   [2,0] ,   ['nombre']    ]
# Out:
#   nombre
# 2      C
# 0      A

# %%
df_total.iloc[   [2,0] ,   ['nombre']    ]

# sale error, debería cambiar ['nombre'] por [0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df_total.iloc[   [2,0] ,   ['nombre']    ]
#
# File c:\Users\AnaGu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\AnaGu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# -> 1690     tup = self._validate_tuple_indexer(tup)
#    1691     with suppress(IndexingError):
# ...

# %%
df_total.iloc[   [2,0] ,   [0]    ]
# Out:
#   nombre
# 2      C
# 0      A
